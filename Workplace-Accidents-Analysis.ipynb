# %% [markdown]
# ### Mini-Project for NUS-ISS Text Analytics
# ##### Objective: Perform text mining on accident reports to determine:
# 1. What are the major types of accidents reflected in the reports?
#     * Identify accident types
# 2. Which type of accidents has the largest number of occurrences?
#     * Count of freq for accident types
# 3. Which part of the human body is injured most?
#     * Identify bodily parts among text
# 4. What are the more risky occupations involved in such accidents?
#     * To extract concept of occupation

# %%
# import packages
import os
import pandas as pd
import string

import nltk
#nltk.download('punkt')
#nltk.download('stopwords')
#nltk.download('wordnet')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import FreqDist, SnowballStemmer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step 1: Data Preparation

# %%
# load accident report dataset
os.chdir(r"C:\Users\desmo\OneDrive\05_Learning\NUS-ISS Text Analytics_060921-080921\Day 1")
df = pd.read_csv("osha.txt", sep='\t', header=None)
df.shape
# Out:
# (10000, 3)

# %%
# rename columns
df = df.rename(columns={0: "id", 1: "title", 2: "text"})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int64
#  1   title   10000 non-null  object
#  2   text    10000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
# word count
df['title_count'] = df['title'].str.split().str.len()
print("Number of words in title and count of titles:\n",\
      df['title_count'].value_counts().sort_values(ascending=False))

df['text_count'] = df['text'].str.split().str.len()
print("Number of words in shortest report: ",min(df['text_count']))
print("Number of words in longest report: ",max(df['text_count']))
# Out:
# Number of words in title and count of titles:
#  7     2481
# 8     2388
# 9     1579
# 6     1516
# 5      657
# 10     503
# 2      390
# 4      239
# 11      99
# 1       85
# 3       54
# 12       8
# 13       1
# Name: title_count, dtype: int64
# Number of words in shortest report:  3
# Number of words in longest report:  730

# %%
# check number of tokens for longest report
text = df['text'].tolist()
text_token = [word_tokenize(t) for t in text]
print("Number of tokens in longest report: ", len(max(text_token)))
# Out:
# Number of tokens in longest report:  722

# %%
# looking at the three word reports
three_word_text = df[df['text_count']==3]
print(three_word_text['text'])
# Out:
# 15      InspectionOpen DateSICEstablishment Name
# 34      InspectionOpen DateSICEstablishment Name
# 61      InspectionOpen DateSICEstablishment Name
# 187     InspectionOpen DateSICEstablishment Name
# 246     InspectionOpen DateSICEstablishment Name
#                           ...
# 9892    InspectionOpen DateSICEstablishment Name
# 9895    InspectionOpen DateSICEstablishment Name
# 9919    InspectionOpen DateSICEstablishment Name
# 9933    InspectionOpen DateSICEstablishment Name
# 9969    InspectionOpen DateSICEstablishment Name
# Name: text, Length: 217, dtype: object

# %%
# pre-processing
stopword = stopwords.words('english')
#snowball = SnowballStemmer('english')
lemma = nltk.WordNetLemmatizer()

def preproc(tt):
    token = nltk.word_tokenize(tt.lower())
    token = [lemma.lemmatize(t) for t in token]
    token = [t for t in token if t not in stopword]
    token = [t for t in token if t not in string.punctuation+"'"""]
    #token = [t for t in token if not t.isnumeric()]
    #token = [snowball.stem(t) for t in token]
    return token

# %%
# preproc title col
title = df['title'].tolist()
title_clean = [preproc(t) for t in title]
title_num = [len(t) for t in title_clean]
title_fd = FreqDist(title_num)
title_flat = [t for tt in title_clean for t in tt]
title_flat_fd = FreqDist(title_flat)
print(title_flat_fd.most_common())
# Out:
# [('employee', 7834), ('killed', 2066), ('fall', 1660), ('injured', 1496), ('struck', 1151), ('dy', 984), ("'s", 963), ('worker', 829), ('finger', 810), ('fracture', 645), ('burned', 574), ('crushed', 490), ('shock', 483), ('caught', 475), ('electric', 474), ('falling', 454), ('amputated', 421), ('machine', 405), ('suffers', 400), ('burn', 399), ('truck', 385), ('amputates', 363), ('two', 340), ('explosion', 327), ('hand', 320), ('leg', 310), ('later', 281), ('ladder', 259), ('fire', 254), ('one', 251), ('arm', 249), ('sustains', 241), ('electrocuted', 217), ('injures', 205), ('crane', 204), ('chemical', 181), ('press', 179), ('foot', 170), ('head', 165), ('exposed', 164), ('injury', 161), ('roof', 160), ('run', 150), ('pinned', 144), ('hot', 143), ('collapse', 141), ('line', 140), ('forklift', 139), ('fractured', 138), ('gas', 138), ('saw', 137), ('flash', 136), ('tree', 135), ('tank', 129), ('three', 124), ('power', 119), ('lift', 118), ('vehicle', 115), ('conveyor', 113), ('back', 108), ('scaffold', 105), ('pipe', 103), ('thumb', 102), ('exposure', 101), ('accident', 101), ('water', 98), ('carbon', 97), ('explodes', 94), ('attack', 94), ('receives', 93), ('concrete', 91), ('vapor', 91), ('cleaning', 90), ('equipment', 90), ('heart', 89), ('metal', 89), ('trailer', 87), ('monoxide', 87), ('drowns', 87), ('tip', 86), ('operator', 85), ('arc', 85), ('car', 83), ('boom', 83), ('elevator', 82), ('contact', 81), ('driver', 81), ('using', 81), ('oil', 81), ('ankle', 80), ('heat', 79), ('strike', 78), ('tractor', 78), ('door', 77), ('bucket', 77), ('electrical', 77), ('steel', 76), ('hospitalized', 74), ('floor', 73), ('roll', 73), ('drill', 73), ('moving', 69), ('four', 69), ('get', 68), ('die', 68), ('lacerates', 67), ('shaft', 67), ('working', 66), ('crush', 66), ('tower', 66), ('roller', 65), ('fingertip', 65), ('load', 65), ('break', 62), ('cut', 62), ('asphyxiated', 62), ('flying', 62), ('wall', 62), ('loader', 62), ('hydraulic', 62), ('beam', 61), ('work', 60), ('trench', 60), ('belt', 59), ('face', 59), ('object', 59), ('kill', 59), ('found', 59), ('wheel', 58), ('grain', 58), ('cable', 57), ('multiple', 57), ('operating', 57), ('log', 56), ('air', 56), ('acid', 56), ('platform', 55), ('dust', 55), ('amputation', 55), ('hip', 54), ('tire', 53), ('ignites', 53), ('bin', 53), ('slip', 52), ('eye', 52), ('rig', 52), ('hit', 52), ('cart', 51), ('part', 51), ('wrist', 50), ('backhoe', 49), ('cutting', 49), ('blade', 48), ('hopper', 48), ('pole', 47), ('jack', 46), ('dead', 46), ('overcome', 46), ('chain', 46), ('asphyxia', 46), ('broken', 45), ('suffer', 44), ('loses', 44), ('opening', 44), ('aerial', 44), ('chlorine', 44), ('lacerated', 43), ('fell', 43), ('fuel', 43), ('overturn', 42), ('rib', 41), ('died', 41), ('inhalation', 41), ('farm', 40), ('construction', 40), ('drum', 39), ('fume', 39), ('mechanic', 39), ('auger', 39), ('motor', 38), ('rotating', 38), ('fails', 38), ('bridge', 38), ('machinery', 38), ('knee', 37), ('rail', 37), ('repairing', 37), ('glass', 37), ('installing', 37), ('shocked', 37), ('trip', 37), ('release', 36), ('well', 36), ('ceiling', 35), ('neck', 35), ('catch', 35), ('fan', 35), ('wire', 34), ('system', 34), ('grinder', 34), ('utility', 34), ('cause', 34), ('coal', 34), ('box', 34), ('hose', 33), ('exhaustion', 33), ('another', 33), ('toe', 33), ('engulfed', 33), ('steam', 33), ('drilling', 33), ('pallet', 32), ('laceration', 32), ('panel', 32), ('dump', 32), ('building', 32), ('dock', 32), ('valve', 31), ('ammonia', 31), ('space', 31), ('aluminum', 31), ('leak', 31), ('block', 31), ('derrick', 31), ('due', 30), ('light', 30), ('pulley', 30), ('plate', 29), ('buried', 29), ('asphalt', 28), ('possible', 28), ('high', 28), ('propane', 28), ('poisoning', 28), ('hydrogen', 28), ('concussion', 28), ('welding', 28), ('mower', 28), ('rolling', 28), ('excavator', 28), ('carpenter', 27), ('pressure', 27), ('ignite', 27), ('piece', 27), ('loading', 27), ('counterweight', 27), ('boiler', 27), ('energized', 27) ...

# %%
# preproc text col
text = df['text'].tolist()
text_clean = [preproc(t) for t in text]
text_num = [len(t) for t in text_clean]
text_fd = FreqDist(text_num)
text_flat = [t for tt in text_clean for t in tt]
text_flat_fd = FreqDist(text_flat)
print(text_flat_fd.most_common())
# Out:
# [('wa', 40175), ('employee', 38347), ('1', 28821), ('approximately', 6070), ("'s", 4240), ('working', 3639), ('hospitalized', 3365), ('coworker', 3354), ('truck', 3135), ('2', 3112), ('hospital', 3065), ('left', 2891), ('hand', 2828), ('fell', 2747), ('right', 2657), ('machine', 2622), ('foot', 2568), ('two', 2533), ('line', 2368), ('injury', 2343), ('a.m.', 2202), ('area', 2116), ('p.m.', 2114), ('one', 2108), ('transported', 2002), ('medical', 1982), ('day', 1881), ('side', 1866), ('back', 1860), ('ground', 1835), ('finger', 1807), ('ft', 1797), ('using', 1774), ('floor', 1744), ('work', 1726), ('employer', 1649), ('sustained', 1644), ('burn', 1640), ('struck', 1602), ('accident', 1563), ('number', 1541), ('operator', 1516), ('head', 1513), ('2013', 1507), ('center', 1502), ('fire', 1472), ('top', 1420), ('tank', 1384), ('3', 1368), ('treated', 1357), ('water', 1354), ('used', 1334), ('died', 1324), ('time', 1320), ('ladder', 1318), ('concrete', 1311), ('worker', 1300), ('2012', 1293), ('company', 1287), ('onto', 1274), ('metal', 1268), ('emergency', 1264), ('power', 1260), ('crane', 1257), ('operating', 1254), ('building', 1245), ('service', 1236), ('killed', 1226), ('arm', 1184), ('three', 1157), ('2011', 1136), ('lift', 1107), ('leg', 1099), ('end', 1086), ('pipe', 1082), ('air', 1075), ('fracture', 1073), ('door', 1064), ('caught', 1063), ('treatment', 1052), ('part', 1049), ('4', 1048), ('taken', 1039), ('fall', 1034), ('forklift', 1016), ('released', 1016), ('system', 1014), ('equipment', 995), ('saw', 987), ('july', 979), ('suffered', 958), ('second', 956), ('cut', 955), ('went', 950), ('site', 935), ('later', 934), ('inside', 931), ('control', 922), ('inc.', 921), ('august', 917), ('june', 917), ('located', 914), ('coworkers', 909), ('roof', 903), ('trailer', 899), ('another', 888), ('front', 880), ('september', 880), ('tree', 869), ('standing', 867), ('causing', 865), ('may', 862), ('crew', 858), ('found', 855), ('first', 851), ('could', 851), ('began', 846), ('wall', 844), ('received', 842), ('removed', 839), ('``', 834), ('supervisor', 827), ('october', 826), ('became', 817), ('press', 809), ('electrical', 806), ("''", 806), ('driver', 801), ('steel', 800), ('10', 799), ('piece', 798), ('cable', 796), ('8', 782), ('room', 781), ('november', 778), ('operation', 776), ('construction', 773), ('face', 773), ('6', 770), ('bucket', 770), ('came', 766), ('incident', 763), ('called', 762), ('caused', 762), ('placed', 762), ('section', 756), ('inch', 749), ('around', 746), ('gas', 746), ('march', 736), ('5', 734), ('started', 732), ('unit', 726), ('body', 725), ('dead', 724), ('electric', 722), ('pulled', 720), ('load', 717), ('pole', 717), ('boom', 713), ('material', 705), ('vehicle', 700), ('car', 699), ('department', 693), ('conveyor', 692), ('20', 688), ('model', 687), ('april', 680), ('box', 680), ('occurred', 679), ('fractured', 672), ('safety', 669), ('12', 669), ('degree', 667), ('valve', 658), ('position', 658), ('2010', 657), ('also', 655), ('away', 647), ('moving', 645), ('would', 635), ('december', 628), ('platform', 628), ('cleaning', 625), ('level', 625), ('bottom', 619), ('new', 614), ('remove', 607), ('point', 602), ('facility', 601), ('four', 601), ('high', 598), ('surgery', 595), ('7', 590), ('chain', 589), ('hour', 588), ('belt', 578), ('2009', 577), ('january', 573), ('place', 572), ('15', 570), ('open', 569), ('wearing', 568), ('wire', 565), ('maintenance', 564), ('turned', 563), ('pressure', 562), ('amputated', 562), ('hole', 561), ('pump', 560), ('hose', 560), ('investigation', 559), ('blade', 559), ('attached', 558), ('long', 557), ('lower', 554), ('hot', 552), ('tractor', 552), ('wheel', 550), ('opening', 550), ('february', 549), ('moved', 546), ('well', 546), ('cutting', 544), ('30', 543), ('contacted', 542), ('near', 540), ('removing', 540), ('due', 539), ('set', 538), ('2008', 532), ('injured', 531), ('ca', 530), ('2007', 530), ('hydraulic', 529), ('installing', 526), ('pronounced', 526), ('perf ...

# %% [markdown]
# ### Step 2: K-Means Clustering to identify themes
# * A clustering approach can be carried out to see if the text reports can be distinguished into different themes

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.preprocessing import Normalizer
#from sklearn.decomposition import TruncatedSVD
#from sklearn.pipeline import make_pipeline

# %% [markdown]
# From the most common words in title and text, add additional stopwords to reduce noise.

# %%
# preprocess in format for tfidf
stopword = stopwords.words('english')+['employee','worker','wa','working','coworker','operator',\
                                       'approximately','a.m.','p.m.','employer','medical',\
                                      'hospital','hospitalized','center']
#snowball = SnowballStemmer('english')
lemma = nltk.WordNetLemmatizer()

def preproc2(tt):
    token = nltk.word_tokenize(tt.lower())
    token = [lemma.lemmatize(t) for t in token]
    token = [t for t in token if t not in stopword]
    token = [t for t in token if t not in string.punctuation+"'"""]
    #token = [t for t in token if not t.isnumeric()]
    #token = [snowball.stem(t) for t in token]
    token = " ".join(token)
    return token

# %%
# Create tfidf matrix on report text
text2 = df['text']
text_clean2 = text2.apply(preproc2)
vectorizer = TfidfVectorizer(max_df=0.7, max_features=2500,
                             min_df=3, stop_words=stopword,
                             use_idf=True)
text_features = vectorizer.fit_transform(text_clean2)
text_features.shape
# Out:
# (10000, 2500)

# %%
# apply K-means method
from sklearn.cluster import KMeans
from sklearn import metrics

# find optimal K based on silhouette score
lst = []
for i in range(2,10):
    km = KMeans(n_clusters=i, init='k-means++', max_iter=2000, random_state=5)
    km.fit(text_features)
    lst.append([i, metrics.silhouette_score(text_features, km.labels_)])
    
cols = ['clusters', 'silhouette_score']
km_df = pd.DataFrame(lst, columns=cols)
print(km_df)
# Out:
#    clusters  silhouette_score
# 0         2          0.034463
# 1         3          0.027144
# 2         4          0.027538
# 3         5          0.029025
# 4         6          0.029965
# 5         7          0.030941
# 6         8          0.031610
# 7         9          0.032071

# %%
# find optimal K using elbow method
sse = []
k_list = list(range(2,10))

for k in k_list:
    km = KMeans(n_clusters=k, init='k-means++', max_iter=2000, random_state=5)
    km.fit(text_features)
    sse.append(km.inertia_)
    
plt.figure()
plt.plot(k_list, sse)
plt.xlabel('Number of clusters')
plt.ylabel('Sum of squared distances')
plt.show()

# %% [markdown]
# * Silhouette scores seem to improve from 5 clusters and above (with exception of k = 2)
# * Optimal K from elbow method non-conclusive, no long tail present
# * Can try to perform clustering on title as well
# * Based on understanding of the reports, seems like there may be around 5 main topics, hence to try k = 5

# %%
# run KM with k = 5
km5 = KMeans(n_clusters=5, init='k-means++', max_iter=2000, random_state=5)
km5.fit(text_features)
    
print("Coefficient for 5 clusters: %0.3f" % metrics.silhouette_score(text_features, km5.labels_))

labels, counts = np.unique(km5.labels_[km5.labels_>=0], return_counts=True)
print(labels)
print(counts)
# Out:
# Coefficient for 5 clusters: 0.029
# [0 1 2 3 4]
# [ 979 1453  217  903 6448]

# %%
# print top terms for each cluster
def print_terms(cm, num, term):
    original_space_centroids = cm.cluster_centers_
    order_centroids = original_space_centroids.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    for i in range(num):
        print("Cluster %d:" % i, end='')
        for ind in order_centroids[i, :term]:
            print(' %s' % terms[ind], end='')
        print()

print_terms(km5, 5, 15)
# Out:
# Cluster 0: truck crane trailer driver boom load side dump struck vehicle bed killed cab rear fell
# Cluster 1: machine finger hand press right left amputated caught conveyor blade index number belt amputation saw
# Cluster 2: datesicestablishment inspectionopen name zone excess except excavator excavation examiner examined examination evidence exchanger eventually event
# Cluster 3: line power electrical electrocuted energized pole electric volt contacted shock conductor overhead phase burn meter
# Cluster 4: fell ft foot floor injury ladder died tank killed struck two fire transported area 2013

# %% [markdown]
# Based on the above, Cluster 2 does not seem to be very informative. 4 clusters may be more relevant.

# %% [markdown]
# ### Step 3: LDA model to identify topics
# * A topic modelling approach like LDA can also be used to draw out main topics from the sea of unstructured text

# %%
# preprocess data for DTM
stopword = stopwords.words('english')+['employee','worker','wa','working','coworker','operator',\
                                       'approximately','a.m.','p.m.','employer','medical',\
                                      'hospital','hospitalized','center']
#snowball = SnowballStemmer('english')
lemma = nltk.WordNetLemmatizer()

def preproc3(tt):
    token = nltk.word_tokenize(tt.lower())
    token = [lemma.lemmatize(t) for t in token]
    token = [t for t in token if t not in stopword]
    token = [t for t in token if t not in string.punctuation+"'"""]
    return token

text3 = df['text']
text_clean3 = text3.apply(preproc3)

# %%
# construct DTM
import gensim 
from gensim import corpora

dictionary = corpora.Dictionary(text_clean3)
#print(dictionary)
dictionary.filter_extremes(no_below=2, no_above=0.8)
dtm = [dictionary.doc2bow(d) for d in text_clean3]

# %% [markdown]
# Initially, number of topics was set as 5 based on observation from K-means clustering. However, we noticed that 2 topics overlapped quite significantly and hence number of topics was eventually set as 4.

# %%
# apply LDA model
lda = gensim.models.ldamodel.LdaModel(dtm, num_topics = 4, id2word = dictionary, passes=10, chunksize=128, random_state=10)
lda.show_topics(10)
# Out:
# [(0,
#   '0.010*"day" + 0.009*"ladder" + 0.009*"floor" + 0.009*"transported" + 0.008*"\'s" + 0.008*"fell" + 0.008*"work" + 0.007*"building" + 0.007*"foot" + 0.006*"roof"'),
#  (1,
#   '0.013*"burn" + 0.011*"tank" + 0.011*"water" + 0.010*"line" + 0.009*"2" + 0.009*"hot" + 0.007*"fire" + 0.007*"power" + 0.006*"gas" + 0.005*"degree"'),
#  (2,
#   '0.026*"machine" + 0.022*"hand" + 0.017*"right" + 0.017*"finger" + 0.016*"left" + 0.012*"\'s" + 0.011*"press" + 0.009*"number" + 0.008*"caught" + 0.006*"metal"'),
#  (3,
#   '0.017*"truck" + 0.011*"car" + 0.010*"struck" + 0.008*"line" + 0.008*"ground" + 0.007*"side" + 0.007*"train" + 0.007*"foot" + 0.007*"fell" + 0.007*"locomotive"')]

# %%
# evaluate coherence score of LDA model
## c_umass: conditional logistic probability of doc occurrence
## c_v: NPMI + cosine similarity
from gensim.models.coherencemodel import CoherenceModel

cm_umass = CoherenceModel(lda,  dictionary=dictionary, corpus=dtm, coherence='u_mass')
cm_cv = CoherenceModel(lda,  dictionary=dictionary, texts=text_clean3, coherence='c_v')
lda_umass = cm_umass.get_coherence()
lda_cv = cm_cv.get_coherence()
print("C_umass score: ",lda_umass) # C_umass: closer to zero the better
print("C_v score: ",lda_cv) # C_v: closer to 1 the better
# Out:
# C_umass score:  -2.1902406296524224
# C_v score:  0.445116311488268

# %%
# visualise LDA model
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

pyLDAvis.enable_notebook()
LDAvis_prepared = gensimvis.prepare(lda, dtm, dictionary)
pyLDAvis.display(LDAvis_prepared)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el2231219216337273128756066937"></div>
# <script type="text/javascript">
#
# var ldavis_el2231219216337273128756066937_data = {"mdsDat": {"x": [-0.09363662185221852, -0.12597154311843892, 0.27233087590954436, -0.05272271093888698], "y": [0.19941102960655038, -0.029636904040793464, 0.018421013433839176, -0.18819513899959622], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [30.355445211306996, 28.601578185998637, 21.31666638887979, 19.726310213814575]}, "tinfo": {"Term": ["machine", "hand", "truck", "finger", "burn", "right", "car", "tank", "left", "press", "ladder", "line", "water", "hot", "floor", "train", "locomotive", "lift", "fell", "caught", "building", "ground", "forklift", "driver", "fire", "struck", "roof", "tree", "load", "number", "ladder", "roof", "scaffold", "house", "home", "ambulance", "office", "report", "bin", "trench", "county", "city", "responded", "boat", "name", "ceiling", "datesicestablishment", "inspectionopen", "paramedic", "joist", "rescue", "pain", "disease", "cal/osha", "summoned", "related", "diagnosed", "felt", "illness", "grain", "carrying", "emergency", "admitted", "san", "building", "floor", "called", "reported", "arrived", "department", "later", "service", "day", "general", "transported", "wall", "hour", "work", "found", "taken", "incident", "contractor", "fell", "treated", "site", "construction", "2012", "died", "foot", "'s", "2011", "2013", "area", "injury", "ft", "accident", "two", "2", "sustained", "truck", "car", "lift", "driver", "forklift", "tree", "trailer", "load", "crane", "train", "locomotive", "vehicle", "rail", "cable", "pole", "loader", "pallet", "railroad", "cab", "track", "loading", "bridge", "tractor", "rear", "boom", "overhead", "dock", "tire", "hoist", "jack", "crossing", "struck", "killed", "bucket", "ground", "side", "line", "front", "ft", "moving", "crew", "fell", "foot", "head", "back", "two", "injury", "'s", "one", "top", "2", "burn", "tank", "hot", "gas", "conductor", "hose", "electrical", "valve", "fuel", "energized", "pump", "vapor", "chemical", "electrocuted", "flash", "explosion", "acid", "second-degree", "liquid", "ignited", "oil", "leak", "percent", "phase", "burned", "contained", "hydrogen", "gallon", "test", "circuit", "ladle", "steam", "degree", "water", "pressure", "air", "face", "power", "electric", "fire", "light", "line", "2", "system", "drum", "lead", "3", "one", "two", "area", "used", "using", "machine", "finger", "press", "amputated", "index", "middle", "conveyor", "blade", "amputation", "guard", "table", "roller", "ring", "button", "die", "activated", "thumb", "ram", "curtain", "rotating", "amputating", "drill", "lathe", "partial", "cutter", "mold", "pedal", "guarded", "fingertip", "cycle", "laser", "kiln", "draw", "hand", "shaft", "violation", "caught", "cutting", "right", "piece", "left", "serial", "number", "reached", "model", "point", "'s", "operating", "cut", "operation", "metal", "saw", "arm", "control", "part", "using", "door", "accident"], "Freq": [2900.0, 2830.0, 2708.0, 1916.0, 1635.0, 2768.0, 1772.0, 1334.0, 2933.0, 1193.0, 1552.0, 2548.0, 1523.0, 1037.0, 1740.0, 1164.0, 1141.0, 1114.0, 2522.0, 1016.0, 1412.0, 1784.0, 989.0, 982.0, 1506.0, 1808.0, 985.0, 925.0, 919.0, 1577.0, 1551.424579669859, 985.0609792681689, 483.05858208945335, 401.4276625572131, 357.43896549564545, 331.04446200080287, 314.38498130853395, 300.0935379377473, 299.8033073641942, 278.5279377443641, 262.4159608022185, 237.1698896345167, 227.03877371490265, 240.0929246863654, 206.86417309625875, 220.98553131867936, 201.70847584989912, 201.70847584989912, 220.4689100193964, 221.94111452521037, 192.0419867053548, 179.90417626968792, 177.27789880644272, 172.00894576189364, 172.0449249251036, 171.50022134501734, 154.44264309744403, 161.47479673547107, 154.00197892855476, 155.04000599031352, 297.8175033253243, 978.6626511688177, 464.68785503770334, 345.50145787061496, 1295.9916990221404, 1550.8534255627321, 563.3245496718313, 446.73086821775973, 384.7217272454805, 680.4573545110233, 933.6314044687047, 916.4567327798336, 1685.4143678419193, 330.17221 ...

# %% [markdown]
# A lambda value of 0.6 appears to be effective in picking out the top relevant terms for each topic.

# %% [markdown]
# #### Question 1: What are the major types of accidents reflected in the reports?
#
# Based on the 4 topics, the main themes identified are:
# * Cluster 0: Fall-related accidents e.g. fall from roof
# * Cluster 1: Fire/electric/gas related accidents e.g. explosions, flash fires
# * Cluster 2: Machine-related accidents e.g. cuts, amputations
# * Cluster 3: Vehicular accidents e.g. forklift, truck

# %%
# add labels to topics based on observation
dict = {0: 'fall', 1: 'fire', 2: 'machine', 3: 'vehicle'}

# get topic distribution of documents
doc_topics = lda.get_document_topics(dtm)

from operator import itemgetter
# show the topic distributions for the first 10 docs
for i in range(0, 10):
    print(doc_topics[i])
    print(max(doc_topics[i], key=itemgetter(1))[0])
# Out:
# [(0, 0.26335874), (1, 0.3349959), (3, 0.3989527)]
# 3
# [(0, 0.22765592), (3, 0.7533047)]
# 3
# [(0, 0.4375805), (2, 0.035577316), (3, 0.52227616)]
# 3
# [(0, 0.13666488), (1, 0.14301474), (2, 0.20729439), (3, 0.513026)]
# 3
# [(0, 0.08884344), (1, 0.6412622), (2, 0.07818504), (3, 0.19170932)]
# 1
# [(0, 0.45756027), (1, 0.41209266), (2, 0.12301386)]
# 0
# [(0, 0.101972364), (1, 0.18397532), (2, 0.52656305), (3, 0.18748923)]
# 2
# [(0, 0.39974663), (2, 0.038795847), (3, 0.55600595)]
# 3
# [(0, 0.3562691), (3, 0.624617)]
# 3
# [(0, 0.8678843), (3, 0.11545771)]
# 0
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# Here, we can see that for some documents e.g. index 0 and 5, there isn't a very clear and distinct category that stands out based on the probability distribution. This highlights the possibility of using other soft classification methods to explore if certain documents could have multiple topic labels.

# %%
# select the best topic (with highest score) for each document
top_topic = [max(t, key=itemgetter(1))[0] for t in doc_topics]
#print(top_topic)

topics_perDoc = [dict[t] for t in top_topic]
print(topics_perDoc)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['vehicle', 'vehicle', 'vehicle', 'vehicle', 'fire', 'fall', 'machine', 'vehicle', 'vehicle', 'fall', 'machine', 'fall', 'machine', 'machine', 'vehicle', 'fall', 'fire', 'vehicle', 'fall', 'machine', 'fall', 'machine', 'fall', 'fall', 'machine', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'vehicle', 'fall', 'vehicle', 'machine', 'machine', 'machine', 'machine', 'fire', 'fire', 'fire', 'machine', 'fire', 'fall', 'machine', 'vehicle', 'vehicle', 'fire', 'vehicle', 'fall', 'machine', 'fire', 'machine', 'fire', 'machine', 'fall', 'vehicle', 'fire', 'fall', 'machine', 'machine', 'fall', 'vehicle', 'machine', 'vehicle', 'machine', 'machine', 'vehicle', 'fire', 'vehicle', 'vehicle', 'machine', 'machine', 'machine', 'machine', 'vehicle', 'fall', 'fall', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'vehicle', 'machine', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'fall', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'fall', 'machine', 'fire', 'fall', 'machine', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fall', 'fire', 'fall', 'fire', 'fire', 'fall', 'machine', 'fire', 'fall', 'fire', 'fire', 'fall', 'fire', 'fire', 'machine', 'fall', 'fire', 'fire', 'fire', 'fall', 'fire', 'fire', 'fire', 'fall', 'fire', 'fire', 'fire', 'fall', 'fire', 'fire', 'vehicle', 'fire', 'vehicle', 'fire', 'fall', 'fire', 'fire', 'fire', 'vehicle', 'fire', 'fall', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'vehicle', 'fire', 'fall', 'vehicle', 'fall', 'fire', 'fire', 'fall', 'fall', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'fall', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'machine', 'vehicle', 'fall', 'machine', 'fall', 'fall', 'fall', 'fall', 'machine', 'fall', 'fire', 'fall', 'machine', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'fall', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'vehicle', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'machine', 'machine', 'fall', 'fall', 'fire', 'fall', 'machine', 'fire', 'fire', 'fire', 'vehicle', 'fall', 'fall', 'fire', 'fall', 'fire', 'fall', 'fall', 'fall', 'fall', 'fire', 'fall', 'fire', 'fire', 'fire', 'fall', 'fire', 'fire', 'fall', 'fall', 'fall', 'fall', 'fall', 'fall', 'machine', 'machine', 'machine', 'machine', 'machine', 'machine', 'vehicle', 'fire', 'fire', 'machine', 'machine', 'fall', 'machine', 'machine', 'machine', 'fall', 'machine', 'vehicle', 'machine', 'machine', 'machine', 'machine', 'machine', 'fire', 'machine', 'machine', 'machine', 'vehicle', 'vehicle', 'fire', 'vehicle', 'vehicle', 'machine', 'vehicle', 'fire', 'fire', 'fall', 'fall', 'fall', 'fall', 'fire', 'fire', 'fall', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fire', 'fall', 'fire', 'fall', 'fall', 'fall', 'fire', 'fall', 'fall', 'fall', 'fall', 'fall', 'fire', 'fall', 'fire', 'fall', 'machine', 'machine', 'machine', 'vehicle', 'vehicle', 'vehicle', 'fire', 'machine', 'fire', 'vehicle', 'vehicle', 'fire', 'fire', 'fire', 'vehicle', 'vehicle', 'vehicle', 'fire', 'fall', 'fire', 'fire', 'vehicle', 'fall', 'fire', 'fall', 'fire', 'fire', 'fire', 'fall', 'fall', 'machine', 'machine', 'fire', 'fall', 'vehicle', 'fall', 'fire', 'fall', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'fall', 'fall', 'fall', 'fall', 'vehicle', 'vehicle', 'vehicle', 'fall', 'vehicle', 'v ...

# %%
# count freq of each topic
print("\033[1m"+"Question 2: Which type of accidents has the largest number of occurrences?"+"\033[0m")
print("")
print("Number of reports involving falls: ",topics_perDoc.count('fall'))
print("Number of reports involving fire/electric/gas: ",topics_perDoc.count('fire'))
print("Number of reports involving machines/cuts: ",topics_perDoc.count('machine'))
print("Number of reports involving vehicles: ",topics_perDoc.count('vehicle'))
print("Total number of reports: ",len(topics_perDoc))
# Out:
# Question 2: Which type of accidents has the largest number of occurrences?
#
# Number of reports involving falls:  3019
# Number of reports involving fire/electric/gas:  2117
# Number of reports involving machines/cuts:  1747
# Number of reports involving vehicles:  3117
# Total number of reports:  10000
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# We can see that accidents involving vehicular-related events have the largest number of occurrences, with incidents involving falls following closely behind.

# %%
# add topic category back to dataframe
df['topic'] = topics_perDoc
pd.set_option("display.max_colwidth", -1)
df.head(6)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#           id                                                        title  \
# 0  201079928   Employee Is Burned By Forklift Radiator Fluid
# 1  202561825   Employee Falls From Flatbed Trailer And Later Dies
# 2  200361855   Two Workers Are Struck By Motor Vehicle And One Is Killed
# 3  200361863   Employee Is Struck By Bales Of Wire And Killed
# 4  201079324   Employee Is Splashed With Hot Water And Is Burned
# 5  202658258   Employee Suffers Burns While Moving Soup
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                text  \
# 0   At approximately 11:30 a.m. on November 13  2013  Employee #1  with Edco Waste  & Recycling Services  was operating a forklift (Linde Lift Truck; Serial  Number: H2X393S04578; identified by the employer as FL-3) from approximately  4:00 a.m.  moving bales of recyclable paper products from a collection area in  the yard into trucks. Then  Employee #1 cleaned and was replacing an air  filter on the forklift FL-3. To clean out the air filter  Employee #1 parked  FL-3 in the doorway of the maintenance building. The air filter was located on  the rear of the forklift  behind the cab frame on the driver's side. Employee  #1 removed the air filter and cleaned it out  and then he climbed up onto the  back of the forklift to replace it. While up on the back of the forklift   Employee #1's foot dislodged the cooling system radiator cap. The fluid in the  lift truck's cooling system was hot and under pressure from being operated all  morning. The hot fluid sprayed up and out of the reservoir. Employee #1 was  burned on the upper legs and the groin area. Employee #1 jumped off of the  back of the forklift onto the ground. Coworkers came to his assistance and  called emergency services. Employee #1 was hospitalized at a burn center for  over 24 hours  for treatment of second degree burns to the upper legs and  groin area.
# 1   On August 30  2013  Employee #1 was working from a flatbed trailer. As he  worked  he fell from the flatbed trailer onto the ground  striking his  abdomen. The fall height of the flatbed trailer was 57 inches. Employee #1  sustained unspecified injuries in the fall that later on caused his death.
# 2   On August 27  2013  Employees #1 and #2  of Templar Inc.  a construction  company specializing in fiber optic installation and services  were working  along a highway. The highway speed limit was posted at 55 miles per hour.  Employee #1 was marking the location of an underground line that ran below the  turn lane. Employee #2 was next to Employee #1 and performing the duties of a  flagger. A privately owned vehicle was travelling in the travel/through lane.  The vehicle veered to the right  entered the turn lane  and struck both  workers. Emergency medical services were called. Employee #1 was declared dead  at the scene. Employee #2 refused emergency medical treatment for the bruises  he received when struck.
# 3   On August 26  2013  Employee #1  with Lee Iron and Metal Company  Inc.  was  using a forklift (Hyster 50 sit down rider) to move and stack bundled cubes of  recycled insulated co-axial (coax) cable and insulated copper wire. The cubes  weighed anywhere from 1 000 to 2 000 lbs. Employee #1 had completed stacking  one column  consisting of five cubes in height  along the northeast wall of  the recycling warehouse. Employee #1 was beginning a new second column  directly in front of the existing first column. Employee #1 placed the first  cube of the second column tight against the bottom cube of the existing first  column. Employee #1 then backed the forklift up  approximately 5 ft  and  exited the forklift. Employee #1 then stepped in between the forklift and the  cubes to either clean off the top from possible loose wires that created a  hump or to place 4 ft by 4 ft dunnage so the next cube could be stacked. The  five tier stack of cubes began to overturn. The first one went over Employee  #1's head and settled on the forks. The second cube (weighing 1 948 lbs)  struck Employee #1 on the left side of his face and upper torso and forced him  back and down. Employee #1 was pinned between the first cube that fell and  second cube. A third cube also fell  which struck Employee #1's legs. Employee  #1 received a puncture wound to the right abdomen area which caused increased  blood loss. According to the medical examiner's report  Employee #1 died at  the scene from blunt force trauma to the head.
# 4   On July 14  2013  Employee #1  vacuum pump truck driver and operator  was  offloading hot brine water at a geothermal power plant. He was assigned to  transfer loads of the brine between power plants and had already made several  trips between facilities. When he arrived at the plant  Employee #1 connected  the hose to the vehicle's tank outlet valve and proceeded to empty the tanks  contents by gravity. While the tank was left emptying  he went inside the  plant's control center briefly to cool off and to get a drink of water.  Employee #1 noticed that the flow of brine had stopped due to a clog in the  hose when he returned. He tried to clear the hose by switching the truck to  vacuum. As he did this  he noticed that the flow was still impeded. Employee  #1 loosened the hose coupler on the truck's valve  which caused hot  pressurized brine to flow out. He attempted to hold the hose  but eventually  let go  causing the hot brine water to splash on his left abdomen  right leg   left leg and left shoulder. Employee #1 rushed into the control room and  removed his hot brine soaked clothing. A coworker observed the pump truck with  the brine pouring out and Employee #1 running toward the control room. This  coworker shut off the valve on the pump truck and went to check on Employee  #1. Employee #1 was taken to a hospital and was then transferred to the burn  unit of a medical center. He was admitted to the medical center  where he was  treated for second and third-degree burns and then hospitalized.
# 5   On June 30  2013  Employee #1 was working in a food Taqueria for a  supermarket. The employee was in the kitchen area transferring soup from the  kitchen area to a refrigerator. While in the refrigerator  the employee lifted  the pail while hot and the pail was soft due to the heat  it folded causing  the liquid to spill on her the employee's arm  chest and abdomen area.  Employee #1 was transported to an area hospital  where she was treated for  second and third degree burns and remains hospitalized.
#
#    title_count  text_count    topic
# 0  7            229         vehicle
# 1  8            51          vehicle
# 2  11           117         vehicle
# 3  9            267         vehicle
# 4  9            270         fire
# 5  6            88          fall

# %% [markdown]
# If we look at the probability distribution across topics for index 0 and 5 again:
#
# Index 0: [('fall', 0.26335874), ('fire', 0.3349959), ('vehicle', 0.3989527)]; model prediction: 'vehicle'
# * Here we see that the prediction probabilities of 'fire' and 'vehicle' are quite close, which corroborates with the report as the employee was burned by the radiator fluid within the forklift. There are multiple terms suggested both the topics of fire/gas/electric and vehicle related incidents.
#
# Index 5: [('fall', 0.45756027), ('fire', 0.41209266), ('machine', 0.12301386)]; model prediction: 'fall'
# * This is a rather unique entry. The text report does not seem to have any indication of a fall or have terms related to falls, yet the model predicted it to be within the fall-related incidents category. 'fire' was rather close behind, and it was understandable why as there were terms such as 'burns' and 'heat'.

# %%
# save LDA model
from gensim.test.utils import datapath

temp_file = datapath("LDA_model")
lda.save(temp_file)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Step 4: Extract concept of body parts and occupation from the accident reports

# %%
# review some examples of accident reports to see if body parts or occupations are mentioned
pd.set_option("display.max_colwidth", -1)
df['text'].head(3)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0     At approximately 11:30 a.m. on November 13  2013  Employee #1  with Edco Waste  & Recycling Services  was operating a forklift (Linde Lift Truck; Serial  Number: H2X393S04578; identified by the employer as FL-3) from approximately  4:00 a.m.  moving bales of recyclable paper products from a collection area in  the yard into trucks. Then  Employee #1 cleaned and was replacing an air  filter on the forklift FL-3. To clean out the air filter  Employee #1 parked  FL-3 in the doorway of the maintenance building. The air filter was located on  the rear of the forklift  behind the cab frame on the driver's side. Employee  #1 removed the air filter and cleaned it out  and then he climbed up onto the  back of the forklift to replace it. While up on the back of the forklift   Employee #1's foot dislodged the cooling system radiator cap. The fluid in the  lift truck's cooling system was hot and under pressure from being operated all  morning. The hot fluid sprayed up and out of the reservoir. Employee #1 was  burned on the upper legs and the groin area. Employee #1 jumped off of the  back of the forklift onto the ground. Coworkers came to his assistance and  called emergency services. Employee #1 was hospitalized at a burn center for  over 24 hours  for treatment of second degree burns to the upper legs and  groin area.
# 1     On August 30  2013  Employee #1 was working from a flatbed trailer. As he  worked  he fell from the flatbed trailer onto the ground  striking his  abdomen. The fall height of the flatbed trailer was 57 inches. Employee #1  sustained unspecified injuries in the fall that later on caused his death.
# 2     On August 27  2013  Employees #1 and #2  of Templar Inc.  a construction  company specializing in fiber optic installation and services  were working  along a highway. The highway speed limit was posted at 55 miles per hour.  Employee #1 was marking the location of an underground line that ran below the  turn lane. Employee #2 was next to Employee #1 and performing the duties of a  flagger. A privately owned vehicle was travelling in the travel/through lane.  The vehicle veered to the right  entered the turn lane  and struck both  workers. Emergency medical services were called. Employee #1 was declared dead  at the scene. Employee #2 refused emergency medical treatment for the bruises  he received when struck.
# Name: text, dtype: object

# %%
# import WordNet as a lexical resource
import nltk
from nltk.corpus import wordnet as wn
from nltk import word_tokenize, pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
#nltk.download('universal_tagset')
nltk.download('wordnet')
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\desmo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# #### Dictionary of body parts

# %%
# use hyponymy of suitable parent word to define dictionary of body parts
# using 'hand' as an example on http://wordnetweb.princeton.edu/, explore inherited hypernyms -- "body part" seems reasonable
ss1 = wn.synsets('body_part')[0]
print(ss1)
# Out:
# Synset('body_part.n.01')
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# view all hyponyms of "body part"
ss1.hyponyms()
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [Synset('abdomen.n.01'),
#  Synset('adnexa.n.01'),
#  Synset('ambulacrum.n.01'),
#  Synset('ampulla.n.01'),
#  Synset('apparatus.n.02'),
#  Synset('area.n.03'),
#  Synset('back.n.01'),
#  Synset('buttock.n.01'),
#  Synset('buttocks.n.01'),
#  Synset('cannon.n.05'),
#  Synset('dilator.n.01'),
#  Synset('dock.n.06'),
#  Synset('dorsum.n.02'),
#  Synset('energid.n.01'),
#  Synset('external_body_part.n.01'),
#  Synset('feature.n.02'),
#  Synset('flank.n.04'),
#  Synset('fornix.n.01'),
#  Synset('gaskin.n.01'),
#  Synset('groove.n.03'),
#  Synset('haunch.n.01'),
#  Synset('hindquarters.n.02'),
#  Synset('hip.n.01'),
#  Synset('horseback.n.01'),
#  Synset('joint.n.01'),
#  Synset('lobe.n.01'),
#  Synset('loin.n.02'),
#  Synset('loins.n.02'),
#  Synset('mentum.n.03'),
#  Synset('organ.n.01'),
#  Synset('partition.n.03'),
#  Synset('process.n.05'),
#  Synset('rectum.n.01'),
#  Synset('rudiment.n.02'),
#  Synset('saddle.n.06'),
#  Synset('shank.n.02'),
#  Synset('shin.n.01'),
#  Synset('shoulder.n.01'),
#  Synset('small.n.01'),
#  Synset('structure.n.04'),
#  Synset('stump.n.02'),
#  Synset('system.n.06'),
#  Synset('thorax.n.01'),
#  Synset('thorax.n.02'),
#  Synset('thorax.n.03'),
#  Synset('tissue.n.01'),
#  Synset('toe.n.03'),
#  Synset('torso.n.01'),
#  Synset('underpart.n.01'),
#  Synset('venter.n.04'),
#  Synset('withers.n.01')]

# %%
# save all body part words as a list
body = list(set(
                [b.replace('_', ' ').lower() for s in ss1.closure(lambda s:s.hyponyms())
                        for b in s.lemma_names()]))
print("Number of words: ",len(body))
sorted(body)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Number of words:  3104
# ['ab',
#  'abdomen',
#  'abdominal',
#  'abdominal aorta',
#  'abdominal cavity',
#  'abdominal external oblique muscle',
#  'abdominal muscle',
#  'abdominal nerve plexus',
#  'abducens',
#  'abducens muscle',
#  'abducens nerve',
#  'abducent',
#  'abducent nerve',
#  'abductor',
#  'abductor muscle',
#  'abomasum',
#  'acanthion',
#  'accessory cephalic vein',
#  'accessory hemiazygos vein',
#  'accessory hemiazygous vein',
#  'accessory nerve',
#  'accessory vertebral vein',
#  'accompanying vein',
#  'acetabulum',
#  'achilles tendon',
#  'acinus',
#  'acoustic meatus',
#  'acoustic nerve',
#  'acromial process',
#  'acromion',
#  'acrosome',
#  'aculea',
#  'aculeus',
#  'acumen',
#  "adam's apple",
#  'adductor',
#  'adductor muscle',
#  'adenohypophysis',
#  'adenoid',
#  'adhesion',
#  'adipose tissue',
#  'adnexa',
#  'adrenal',
#  'adrenal cortex',
#  'adrenal gland',
#  'adrenal medulla',
#  'adult tooth',
#  'adventitia',
#  'afferent',
#  'afferent nerve',
#  'afterbirth',
#  'agnail',
#  'agonist',
#  'air bladder',
#  'air cell',
#  'air sac',
#  'airway',
#  'ala',
#  'albuginea',
#  'alimentary canal',
#  'alimentary tract',
#  'allantois',
#  'allograft',
#  'alpha receptor',
#  'alpha-adrenergic receptor',
#  'alpha-adrenoceptor',
#  'alveolar arch',
#  'alveolar artery',
#  'alveolar bed',
#  'alveolar point',
#  'alveolar process',
#  'alveolar ridge',
#  'alveolus',
#  'ambulacrum',
#  'amnion',
#  'amnios',
#  'amniotic cavity',
#  'amniotic sac',
#  'ampulla',
#  'amygdala',
#  'amygdaloid nucleus',
#  'anal sphincter',
#  'anastomotic vein',
#  'anatomical sphincter',
#  'anatomical structure',
#  'anconeous muscle',
#  'angular artery',
#  'angular vein',
#  'animal foot',
#  'animal leg',
#  'animal tissue',
#  'ankle',
#  'ankle joint',
#  'anklebone',
#  'anlage',
#  'annexa',
#  'annualry',
#  'ans',
#  'antagonist',
#  'antagonistic muscle',
#  'antenna',
#  'anterior',
#  'anterior cardinal vein',
#  'anterior cerebral artery',
#  'anterior cerebral vein',
#  'anterior crural nerve',
#  'anterior facial vein',
#  'anterior fontanelle',
#  'anterior horn',
#  'anterior jugular vein',
#  'anterior labial veins',
#  'anterior meningeal artery',
#  'anterior naris',
#  'anterior pituitary',
#  'anterior pituitary gland',
#  'anterior root',
#  'anterior serratus muscle',
#  'anterior temporal artery',
#  'anterior vertebral vein',
#  'antler',
#  'antrum',
#  'anus',
#  'anvil',
#  'aorta',
#  'aortic arch',
#  'aortic orifice',
#  'aortic plexus',
#  'aortic valve',
#  'apocrine gland',
#  'apodeme',
#  'aponeurosis',
#  'apophysis',
#  'apparatus',
#  'apparatus urogenitalis',
#  'appendage',
#  'appendicular artery',
#  'appendicular skeleton',
#  'appendicular vein',
#  'appendix',
#  'aqueductus cerebri',
#  'arachnoid',
#  'arachnoid membrane',
#  'arch',
#  'archenteron',
#  'archipallium',
#  'arcuate artery',
#  'arcuate artery of the kidney',
#  'arcuate vein of the kidney',
#  'arcus',
#  'arcus senilis',
#  'arcus zygomaticus',
#  'area',
#  'area 17 of brodmann',
#  'area of cardiac dullness',
#  'areola',
#  'areolar tissue',
#  'areteria cervicalis',
#  'arista',
#  'arm',
#  'arm bone',
#  'armpit',
#  'arse',
#  'arsehole',
#  'arteria',
#  'arteria alveolaris',
#  'arteria alveolaris inferior',
#  'arteria alveolaris superior',
#  'arteria angularis',
#  'arteria appendicularis',
#  'arteria arcuata',
#  'arteria ascendens',
#  'arteria auricularis',
#  'arteria axillaris',
#  'arteria basilaris',
#  'arteria brachialis',
#  'arteria buccalis',
#  'arteria bulbi penis',
#  'arteria bulbi vestibuli',
#  'arteria carotis',
#  'arteria celiaca',
#  'arteria centralis retinae',
#  'arteria cerebelli',
#  'arteria cerebri',
#  'arteria choroidea',
#  'arteria ciliaris',
#  'arteria circumflexa femoris',
#  'arteria circumflexa humeri',
#  'arteria circumflexa ilium',
#  'arteria circumflexa scapulae',
#  'arteria colica',
#  'arteria communicans',
#  'arteria coronaria',
#  'arteria cystica',
#  'arteria digitalis',
#  'arteria epigastrica',
#  'arteria ethmoidalis',
#  'arteria facialis',
#  'arteria femoralis',
#  'arteria gastrica',
#  'arteria gastrica breves',
#  'arteria gastrica sinistra',
#  'arteria glutes',
#  'arteria hepatica',
#  'arteria ileocolica',
#  'arteria ileum',
#  'arteria iliaca',
#  'arteria iliolumbalis',
#  'arteria infraorbitalis',
#  'arteria intercostalis',
#  'arteria labialis',
#  'arteria labialis inferior',
#  'arteria labialis superior',
#  'arteria lacrimalis',
#  'arteria laryngea',
#  'arteria lienalis',
#  'arteria lingualis',
#  'arteria lumbalis',
#  'arteria maxillaris',
#  'arteria meningea',
#  'arteria mesenterica',
#  'arteria metacarpea',
#  'arteria metatarsea',
#  'arteria musculophrenica',
#  'arteria nutricia',
#  'arteria ophthalmica',
#  'arteria ovarica',
#  'arteria palatina',
#  'arteria pancreatica',
#  'arteria perinealis',
#  'arteria poplitea',
#  'arteria pudenda',
#  'arteria pulmonalis',
#  'arteria radialis',
#  'arteria rectalis',
#  'arteria renalis',
#  'arteria subclavia',
#  'arteria temporalis anterior',
#  'arteria temporalis intermedia',
#  'arteria temporalis posterior',
#  'arteria testicularis',
#  'arteria ulnaris',
#  'arteria uterina',
#  'arteria vaginalis',
#  'arteria vertebralis',
#  'arterial blood vessel',
#  'arteriola',
#  'arteriole',
#  'artery',
#  'artery of the labyrinth',
#  'artery of the penis bulb',
#  'artery of the vestibule bulb',
#  'arthromere',
#  'articular muscle',
#  'articulatio',
#  'articulatio coxae',
#  'articulatio cubiti',
#  'articulatio genus',
#  'articulatio humeri',
#  'articulatio plana',
#  'articulatio radiocarpea',
#  'articulatio spheroidea',
#  'articulatio synovialis',
#  'articulatio talocruralis',
#  'articulatio temporomandibularis',
#  'articulatio trochoidea',
#  'articulation',
#  'articulator',
#  'articulatory system',
#  'arytaenoid',
#  'arytenoid',
#  'arytenoid cartilage',
#  'ascending aorta',
#  'ascending artery',
#  'ascending colon',
#  'ass',
#  'asshole',
#  'association area',
#  'association cortex',
#  'aster',
#  'asterion',
#  'astragal',
#  'astragalus',
#  'astroglia',
#  'ateria gastrica dextra',
#  'atheroma',
#  "athlete's heart",
#  'atlas',
#  'atlas vertebra',
#  'atrial artery',
#  'atrial auricle',
#  'atrioventricular bundle',
#  'atrioventricular node',
#  'atrioventricular trunk',
#  'atrioventricular valve',
#  'atrium',
#  'atrium cordis',
#  'atrium dextrum',
#  'atrium of the heart',
#  'atrium sinistrum',
#  'attic',
#  'auditory apparatus',
#  'auditory area',
#  'auditory canal',
#  'auditory center',
#  'auditory cortex',
#  'auditory meatus',
#  'auditory nerve',
#  'auditory ossicle',
#  'auditory system',
#  'auditory tube',
#  'auricle',
#  'auricula',
#  'auricula atrii',
#  'auricular appendage',
#  'auricular appendix',
#  'auricular artery',
#  'auricular point',
#  'auricular vein',
#  'auriculare',
#  'autograft',
#  'autonomic ganglion',
#  'autonomic nervous system',
#  'autonomic plexus',
#  'autoplasty',
#  'awn',
#  'axial muscle',
#  'axial skeleton',
#  'axilla',
#  'axillary artery',
#  'axillary cavity',
#  'axillary fossa',
#  'axillary node',
#  'axillary vein',
#  'axis',
#  'axis vertebra',
#  'axolemma',
#  'azygos vein',
#  'azygous vein',
#  'baby tooth',
#  'back',
#  'back tooth',
#  'backbone',
#  'backside',
#  'bag',
#  'balancer',
#  'ball',
#  'ball-and-socket joint',
#  'ballock',
#  'band',
#  'bandy leg',
#  'bandyleg',
#  'barbel',
#  'bare bone',
#  'baroreceptor',
#  "bartholin's gland",
#  'basal ganglion',
#  'basal vein',
#  'basilar artery',
#  'basilar membrane',
#  'basilic vein',
#  'basivertebral vein',
#  'bay window',
#  'beak',
#  'bean',
#  'bear claw',
#  'beard',
#  'behind',
#  'belly',
#  'beta receptor',
#  'beta-adrenergic receptor',
#  'beta-adrenoceptor',
#  'betweenbrain',
#  'biauriculate heart',
#  'biceps',
#  'biceps brachii',
#  'biceps humeri',
#  'bicuspid',
#  'bicuspid valve',
#  'big toe',
#  'bile duct',
#  'biliary ductule',
#  'bill',
#  "bird's foot",
#  'birth canal',
#  'bladder',
#  'bladder sphincter',
#  'blade',
#  'blastocele',
#  'blastocoel',
#  'blastocoele',
#  'blastoderm',
#  'blastodisc',
#  'blastopore',
#  'bleb',
#  'blind gut',
#  'blister',
#  'blood blister',
#  'blood vessel',
#  'blowhole',
#  'bob',
#  'bobtail',
#  'bodily cavity',
#  'bodily structure',
#  'body',
#  'body structure',
#  'bollock',
#  'bonce',
#  'bone',
#  'bone marrow',
#  'bonelet',
#  'bony labyrinth',
#  'boob',
#  'book lung',
#  'bosom',
#  'bottom',
#  'bow leg',
#  'bowel',
#  'bowleg',
#  "bowman's capsule",
#  'brachial artery',
#  'brachial plexus',
#  'brachial vein',
#  'brachiocephalic vein',
#  'brain',
#  'brain stem',
#  'brain-stem',
#  'braincase',
#  'brainpan',
#  'brainstem',
#  'branchia',
#  'branchial arch',
#  'branchial cleft',
#  'breadbasket',
#  'breast',
#  'breastbone',
#  'bregma',
#  'bridge',
#  'bristle',
#  "broca's area",
#  "broca's center",
#  "broca's convolution",
#  "broca's gyrus",
#  "brodmann's area",
#  "brodmann's area 17",
#  'bronchial artery',
#  'bronchial tube',
#  'bronchial vein',
#  'bronchiole',
#  'bronchus',
#  'brow',
#  'brush',
#  'bubo',
#  'buccal artery',
#  'buccal cavity',
#  'buccinator muscle',
#  'buccula',
#  'bucktooth',
#  'buff',
#  'bulb',
#  'bulbar conjunctiva',
#  'bulbourethral gland',
#  'bull neck',
#  'bulla',
#  'bullethead',
#  'bum',
#  'bundle of his',
#  'bunghole',
#  'buns',
#  'burl',
#  'bursa',
#  'bursa omentalis',
#  'bust',
#  'butt',
#  'buttock',
#  'buttocks',
#  'button',
#  'bypass',
#  'caecum',
#  'cakehole',
#  'calamus',
#  'calcaneus',
#  'calcarine fissure',
#  'calcarine sulcus',
#  'calf',
#  'calf bone',
#  'caliculus',
#  'callus',
#  'calvaria',
#  'calycle',
#  'calyculus',
#  'can',
#  'canal',
#  'canal of schlemm',
#  'canaliculus',
#  'canalis cervicis uteri',
#  'canalis inguinalis',
#  'canalis vertebralis',
#  'canine',
#  'canine tooth',
#  'cannon',
#  'cannon bone',
#  'capillary',
#  'capillary artery',
#  'capillary bed',
#  'capillary vein',
#  'capillary vessel',
#  'capitate',
#  'capitate bone',
#  'capsula glomeruli',
#  'capsule',
#  'caput',
#  'cardia',
#  'cardiac muscle',
#  'cardiac pacemaker',
#  'cardiac plexus',
#  'cardiac sphincter',
#  'cardiac valve',
#  'cardinal vein',
#  'cardiovascular system',
#  'carina',
#  'carina fornicis',
#  'carnassial tooth',
#  'carotid artery',
#  'carotid body',
#  'carotid plexus',
#  'carpal',
#  'carpal bone',
#  'carpal tunnel',
#  'carpus',
#  'cartilage',
#  'cartilage bone',
#  'cartilaginous structure',
#  'cartilaginous tube',
#  'caruncle',
#  'caruncula',
#  'cauda',
#  'caudal appendage',
#  'caudal fin',
#  'caudal vertebra',
#  'caudate',
#  'caudate nucleus',
#  'caul',
#  'cauliflower ear',
#  'cavernous sinus',
#  'cavity',
#  'cavum',
#  'cecal appendage',
#  'cecum',
#  'celiac artery',
#  'celiac trunk',
#  'cell membrane',
#  'cell nucleus',
#  'cell organ',
#  'cell organelle',
#  'cellulite',
#  'celom',
#  'celoma',
#  'center',
#  'central artery of the retina',
#  'central gyrus',
#  'central nervous system',
#  'central sulcus',
#  'central vein of retina',
#  'central vein of suprarenal gland',
#  'central veins of liver',
#  'centre',
#  'centriole',
#  'centromere',
#  'centrum',
#  'cephalic vein',
#  'ceras',
#  'cere',
#  'cerebellar artery',
#  'cerebellar hemisphere',
#  'cerebellar vein',
#  'cerebellum',
#  'cerebral aqueduct',
#  'cerebral artery',
#  'cerebral cortex',
#  'cerebral hemisphere',
#  'cerebral mantle',
#  'cerebral peduncle',
#  'cerebral vein',
#  'cerebrum',
#  'cervical artery',
#  'cervical canal',
#  'cervical glands',
#  'cervical glands of the uterus',
#  'cervical nerve',
#  'cervical plexus',
#  'cervical vein',
#  'cervical vertebra',
#  'cervix',
#  'cervix uteri',
#  'chaeta',
#  'chalaza',
#  'chamber',
#  'channel',
#  'cheek',
#  'cheek muscle',
#  'cheek pouch',
#  'cheekbone',
#  'chela',
#  'chelicera',
#  'chemoreceptor',
#  'chest',
#  'chest cavity',
#  'chiasm',
#  'chiasma',
#  'chiasma opticum',
#  'chin',
#  'chine',
#  'chondriosome',
#  'chop',
#  'chopper',
#  'chordamesoderm',
#  'chordomesoderm',
#  'chorioallantoic membrane',
#  'chorioallantois',
#  'chorion',
#  'chorionic villus',
#  'choroid',
#  'choroid coat',
#  'choroid plexus',
#  'choroid vein',
#  'choroidal artery',
#  'ciliary artery',
#  'ciliary body',
#  'ciliary veins',
#  'cilium',
#  'cingulate gyrus',
#  'cingulum',
#  'circle of willis',
#  'circulatory system',
#  'circumflex artery',
#  'circumflex artery of the thigh',
#  'circumflex femoral vein',
#  'circumflex humeral artery',
#  'circumflex iliac artery',
#  'circumflex iliac vein',
#  'circumflex scapular artery',
#  'circumflex vein',
#  'cirrus',
#  'cistern',
#  'cisterna',
#  'clapper',
#  'claustrum',
#  'clavicle',
#  'claw',
#  'cleavage',
#  'cleavage cavity',
#  'clenched fist',
#  'clit',
#  'clitoral vein',
#  'clitoris',
#  'cloaca',
#  'cloven foot',
#  'cloven hoof',
#  'cns',
#  'cobblers',
#  'coccygeal nerve',
#  'coccygeal plexus',
#  'coccygeal vertebra',
#  'coccyx',
#  'cochlea',
#  'cock',
#  'cockscomb',
#  'coelenteron',
#  'coeliac plexus',
#  'coelom',
#  'colic artery',
#  'colic vein',
#  'collarbone',
#  'colon',
#  'column',
#  'comb',
#  'comb-plate',
#  'commissure',
#  'common bile duct',
#  'common cardinal vein',
#  'common carotid',
#  'common carotid artery',
#  'common facial vein',
#  'common iliac artery',
#  'common iliac vein',
#  'communicating artery',
#  'complex body part',
#  'compound eye',
#  'concha',
#  'condylar process',
#  'condyle',
#  'condylion',
#  'condyloid process',
#  'conjunctiva',
#  'conjunctival layer of bulb',
#  'conjunctival layer of eyelids',
#  'conjunctival veins',
#  'conk',
#  'connective tissue',
#  'conodont',
#  'contractile organ',
#  'contractor',
#  'convolution',
#  'convolution of broca',
#  'cornea',
#  'cornu',
#  'corona',
#  'coronal suture',
#  'coronary artery',
#  'coronary sinus',
#  'coronet',
#  'coronion',
#  'coronoid process',
#  'coronoid process of the mandible',
#  'corporation',
#  'corpus amygdaloideum',
#  'corpus callosum',
#  'corpus geniculatum laterale',
#  'corpus geniculatum mediale',
#  'corpus luteum',
#  'corpus mamillare',
#  'corpus sternum',
#  'corpus striatum',
#  'cortex',
#  'cortical area',
#  'cortical region',
#  'corticospinal tract',
#  'costa',
#  'costal cartilage',
#  'costal groove',
#  'costoaxillary vein',
#  'cotyloid cavity',
#  'cotyloid joint',
#  'countenance',
#  'cowl muscle',
#  "cowper's gland",
#  'coxa',
#  'coxcomb',
#  'cranial cavity',
#  'cranial nerve',
#  'cranial orbit',
#  'craniometric point',
#  'cranium',
#  'craw',
#  'crazy bone',
#  'crest',
#  'crop',
#  'crotaphion',
#  'crotch',
#  'croup',
#  'croupe',
#  'crus',
#  'crystalline lens',
#  'ctene',
#  'ctenidium',
#  'cubital joint',
#  'cubital nerve',
#  'cubitus',
#  'cuboid bone',
#  'cuneiform bone',
#  'cunt',
#  'cupule',
#  'cusp',
#  'cuspid',
#  'cutaneous vein',
#  'cuticle',
#  'cutis',
#  'cyst',
#  'cystic artery',
#  'cystic vein',
#  'cytomembrane',
#  'cytoskeleton',
#  'cytostome',
#  'dacryocyst',
#  'dacryon',
#  'dactyl',
#  'decidua',
#  'deciduous tooth',
#  'decussation',
#  'deep cervical vein',
#  'deep middle cerebral vein',
#  'deep temporal vein',
#  'deltoid',
#  'deltoid eminence',
#  'deltoid muscle',
#  'deltoid tuberosity',
#  'dentate nucleus',
#  'denticle',
#  'dentin',
#  'dentine',
#  'depressor',
#  'depressor muscle',
#  'depressor nerve',
#  'derriere',
#  'descending aorta',
#  'descending colon',
#  'dewlap',
#  'diaphragm',
#  'diaphysis',
#  'diarthrosis',
#  'dick',
#  'dictyosome',
#  'diencephalon',
#  'digestive gland',
#  'digestive system',
#  'digestive tract',
#  'digestive tube',
#  'digit',
#  'digital arteries',
#  'digital vein',
#  'dilator',
#  'diploic vein',
#  'dock',
#  'dogtooth',
#  'dome',
#  'dorsal fin',
#  'dorsal horn',
#  'dorsal root',
#  'dorsal scapular vein',
#  'dorsal vertebra',
#  'dorsum',
#  'double chin',
#  'duct',
#  'duct gland',
#  'ductless gland',
#  'ductule',
#  'ductulus',
#  'ductus arteriosus',
#  'ductus deferens',
#  'dug',
#  'duodenum',
#  'dura',
#  'dura mater',
#  'ear',
#  'ear canal',
#  'ear lobe',
#  'eardrum',
#  'earlobe',
#  'eccrine gland',
#  'ectoblast',
#  'ectoderm',
#  'effector',
#  'efferent',
#  'efferent nerve',
#  'egg',
#  'eighth cranial nerve',
#  'ejaculatory duct',
#  'elastic tissue',
#  'elbow',
#  'elbow bone',
#  'elbow joint',
#  'eleventh cranial nerve',
#  'elytron',
#  'embryonic membrane',
#  'embryonic tissue',
#  'eminence',
#  'emissary vein',
#  'enarthrodial joint',
#  'enarthrosis',
#  'enation',
#  'encephalon',
#  'end organ',
#  'end-plate',
#  'endoblast',
#  'endocardium',
#  'endocranium',
#  'endocrine',
#  'endocrine gland',
#  'endocrine system',
#  'endoderm',
#  'endometrium',
#  'endoneurium',
#  'endoskeleton',
#  'endosteum',
#  'endothelium',
#  'endplate',
#  'energid',
#  'enteroceptor',
#  'enteron',
#  'entoblast',
#  'entoderm',
#  'entomion',
#  'entrails',
#  'ependyma',
#  'epicanthic fold',
#  'epicanthus',
#  'epicardia',
#  'epicardium',
#  'epicondyle',
#  'epididymis',
#  'epigastric artery',
#  'epigastric fossa',
#  'epigastric vein',
#  'epigastrium',
#  'epiglottis',
#  'epiphysis',
#  'epiphysis cerebri',
#  'episcleral veins',
#  'epithelial duct',
#  'epithelial tissue',
#  'epithelium',
#  'erectile organ',
#  'erectile tissue',
#  'erogenous zone',
#  'esophageal veins',
#  'esophagus',
#  'ethmoid',
#  'ethmoid bone',
#  'ethmoid sinus',
#  'ethmoidal artery',
#  'ethmoidal sinus',
#  'ethmoidal vein',
#  'eustachian tube',
#  'excitable area',
#  'excrescence',
#  'excretory organ',
#  'exocrine',
#  'exocrine gland',
#  'exoderm',
#  'exoskeleton',
#  'extensor',
#  'extensor muscle',
#  'external auditory canal',
#  'external body part',
#  'external carotid',
#  'external carotid artery',
#  'external ear',
#  'external gill',
#  'external iliac artery',
#  'external iliac vein',
#  'external jugular vein',
#  'external maxillary artery',
#  'external nasal vein',
#  'external oblique muscle',
#  'external organ',
#  'external orifice',
#  'exteroceptor',
#  'extremity',
#  'eye',
#  'eye muscle',
#  'eye socket',
#  'eye tooth',
#  'eyeball',
#  'eyecup',
#  'eyelid',
#  'eyetooth',
#  'face',
#  'facia',
#  'facial',
#  'facial artery',
#  'facial muscle',
#  'facial nerve',
#  'facial vein',
#  'falciform ligament',
#  'fallen arch',
#  'fallopian tube',
#  'false glottis',
#  'false vocal cord',
#  'false vocal fold',
#  'family jewels',
#  'fang',
#  'fanny',
#  'fascia',
#  'fascicle',
#  'fasciculus',
#  'fat',
#  'fatty tissue',
#  'fauces',
#  'faucial tonsil',
#  'feature',
#  'feeler',
#  'female chest',
#  'female genital organ',
#  'female genitalia',
#  'female genitals',
#  'female internal reproductive organ',
#  'female reproductive system',
#  'femoral artery',
#  'femoral biceps',
#  'femoral nerve',
#  'femoral vein',
#  'femoris',
#  'femur',
#  'fenestra',
#  'fenestra cochleae',
#  'fenestra of the cochlea',
#  'fenestra of the vestibule',
#  'fenestra ovalis',
#  'fenestra rotunda',
#  'fenestra vestibuli',
#  'fertilization membrane',
#  'fetal circulation',
#  'fetal membrane',
#  'fetlock',
#  'fetlock joint',
#  'fetter bone',
#  'fiber bundle',
#  'fibre bundle',
#  'fibrocartilage',
#  'fibrous joint',
#  ...]

# %% [markdown]
# #### Dictionary of occupations

# %%
# use hyponymy of suitable parent word to define dictionary of occupations
# using 'driver' as an example on http://wordnetweb.princeton.edu/, explore inherited hypernyms -- "worker" seems reasonable
ss2 = wn.synsets('worker')[0]
print(ss2)
# Out:
# Synset('worker.n.01')
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# view all hyponyms of "worker"
ss2.hyponyms()
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [Synset('assistant.n.01'),
#  Synset('beater.n.01'),
#  Synset('bill_poster.n.01'),
#  Synset('bleacher.n.01'),
#  Synset('boatman.n.01'),
#  Synset('carter.n.03'),
#  Synset('caster.n.01'),
#  Synset('charcoal_burner.n.01'),
#  Synset('collector.n.02'),
#  Synset('comber.n.01'),
#  Synset('cornhusker.n.01'),
#  Synset('driver.n.02'),
#  Synset('employable.n.01'),
#  Synset('employee.n.01'),
#  Synset('finisher.n.04'),
#  Synset('freelancer.n.01'),
#  Synset('gutter.n.03'),
#  Synset('hanger.n.01'),
#  Synset('lamplighter.n.01'),
#  Synset('melter.n.01'),
#  Synset('moonlighter.n.01'),
#  Synset('mopper.n.01'),
#  Synset('muzzler.n.01'),
#  Synset('nailer.n.01'),
#  Synset('oiler.n.01'),
#  Synset('part-timer.n.01'),
#  Synset('peeler.n.02'),
#  Synset('planter.n.02'),
#  Synset('plier.n.01'),
#  Synset('processor.n.02'),
#  Synset('pruner.n.01'),
#  Synset('puller.n.02'),
#  Synset('quarryman.n.01'),
#  Synset('ragsorter.n.01'),
#  Synset('scab.n.01'),
#  Synset('scrubber.n.01'),
#  Synset('seasonal_worker.n.01'),
#  Synset('servant.n.01'),
#  Synset('sheller.n.01'),
#  Synset('shelver.n.01'),
#  Synset('shingler.n.01'),
#  Synset('shoveler.n.01'),
#  Synset('skidder.n.02'),
#  Synset('skilled_worker.n.01'),
#  Synset('slave.n.02'),
#  Synset('solderer.n.01'),
#  Synset('splicer.n.02'),
#  Synset('splitter.n.01'),
#  Synset('stainer.n.01'),
#  Synset('stemmer.n.02'),
#  Synset('stringer.n.02'),
#  Synset('stripper.n.02'),
#  Synset('tacker.n.01'),
#  Synset('tapper.n.03'),
#  Synset('teaser.n.01'),
#  Synset('temp.n.01'),
#  Synset('throwster.n.01'),
#  Synset('tier.n.03'),
#  Synset('tiler.n.01'),
#  Synset('toiler.n.01'),
#  Synset('topper.n.01'),
#  Synset('topper.n.02'),
#  Synset('trade_unionist.n.01'),
#  Synset('twiner.n.01'),
#  Synset('volunteer.n.02'),
#  Synset('wallah.n.01'),
#  Synset('washer.n.01'),
#  Synset('winder.n.01'),
#  Synset('wiper.n.01'),
#  Synset('working_girl.n.01'),
#  Synset('workmate.n.01')]

# %%
# save all worker words as a list
worker = list(set(
                [w.replace('_', ' ').lower() for s in ss2.closure(lambda s:s.hyponyms())
                        for w in s.lemma_names()]))
print("Number of words: ",len(worker))
sorted(worker)
# Out:
# Number of words:  1415
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['1st lieutenant',
#  '2nd lieutenant',
#  'abbreviator',
#  'able seaman',
#  'able-bodied seaman',
#  'abridger',
#  'accomplice',
#  'accumulator',
#  "actor's assistant",
#  'adjutant',
#  'adjutant general',
#  'administrative official',
#  'admiral',
#  'aeronaut',
#  'aesthetician',
#  'agent',
#  'agricultural laborer',
#  'agricultural labourer',
#  'aide',
#  'aide-de-camp',
#  'air force officer',
#  'air hostess',
#  'aircraftman',
#  'aircraftsman',
#  'aircrewman',
#  'airman',
#  'airplane pilot',
#  'airwoman',
#  'alcalde',
#  'almoner',
#  'amah',
#  'amanuensis',
#  'ambassador',
#  'ambassadress',
#  'angler',
#  'animal stuffer',
#  'animator',
#  'anthologist',
#  'anzac',
#  'apparatchik',
#  'appointee',
#  'aquanaut',
#  'armiger',
#  'armor-bearer',
#  'armorer',
#  'armourer',
#  'army officer',
#  'arouser',
#  'arrowsmith',
#  'art editor',
#  'artificer',
#  'artilleryman',
#  'artisan',
#  "artist's model",
#  'assessor',
#  'assistant',
#  'associate',
#  'astrogator',
#  'attendant',
#  'attender',
#  'auto-mechanic',
#  'automobile mechanic',
#  'auxiliary',
#  'aviator',
#  'aviatress',
#  'aviatrix',
#  'ayah',
#  'baggageman',
#  'bagger',
#  'bagman',
#  'bailiff',
#  'baker',
#  'balloonist',
#  'barber',
#  'bargee',
#  'bargeman',
#  'barkeep',
#  'barkeeper',
#  'barmaid',
#  'barman',
#  'barnstormer',
#  'barrel maker',
#  'bartender',
#  'baster',
#  'bat boy',
#  'batman',
#  'beadle',
#  'bean counter',
#  'beater',
#  'beautician',
#  'bell founder',
#  'bellboy',
#  'bellhop',
#  'bellman',
#  'best man',
#  'bill poster',
#  'bill sticker',
#  'birthing coach',
#  'black and tan',
#  'blackleg',
#  'blacksmith',
#  'blaster',
#  'bleacher',
#  'blucher',
#  'bluejacket',
#  "bo's'n",
#  "bo'sun",
#  'boater',
#  'boatman',
#  'boatswain',
#  'body servant',
#  'bombardier',
#  'book agent',
#  'bookbinder',
#  "bos'n",
#  'bosun',
#  'bottom dog',
#  'bounty hunter',
#  'bowdleriser',
#  'bowdlerizer',
#  'boxer',
#  'bracero',
#  'brakeman',
#  'brass hat',
#  'bread maker',
#  'breadwinner',
#  'breaker',
#  'bricklayer',
#  'bridesmaid',
#  'brigadier',
#  'brigadier general',
#  'buck private',
#  'buckaroo',
#  'buckeroo',
#  'bunny',
#  'bunny girl',
#  'bureaucrat',
#  'busboy',
#  'bushwhacker',
#  'business editor',
#  'butcher',
#  'butler',
#  'cabin boy',
#  'cabinetmaker',
#  'caddie',
#  'calligrapher',
#  'calligraphist',
#  'candy striper',
#  'cannon fodder',
#  'cannoneer',
#  'canoeist',
#  'canvasser',
#  'captain',
#  'car-mechanic',
#  'carabineer',
#  'carabinier',
#  'carbineer',
#  'caretaker',
#  'carhop',
#  'carpenter',
#  'carrier',
#  'carter',
#  'cartwright',
#  'carver',
#  'caseworker',
#  'caster',
#  "cat's-paw",
#  'cattleman',
#  'cavalryman',
#  'censor',
#  'census taker',
#  'ceramicist',
#  'ceramist',
#  'chambermaid',
#  'char',
#  'charcoal burner',
#  "charge d'affaires",
#  'charge of quarters',
#  'chargeman',
#  'charioteer',
#  'charon',
#  'charwoman',
#  'check girl',
#  'checker',
#  'chef',
#  'chief assistant',
#  'chief justice',
#  'chief of staff',
#  'chief petty officer',
#  'chimneysweep',
#  'chimneysweeper',
#  'church officer',
#  'churchwarden',
#  'city editor',
#  'city father',
#  'civil servant',
#  'cleaner',
#  'cleaning lady',
#  'cleaning woman',
#  'clerk',
#  'clockmaker',
#  'clocksmith',
#  'co-pilot',
#  'coachbuilder',
#  'coachman',
#  'coadjutor',
#  'coal miner',
#  'coalman',
#  'coastguardsman',
#  'cog',
#  'coiffeur',
#  'coiffeuse',
#  'coiner',
#  'collector',
#  'collector of internal revenue',
#  'collier',
#  'colonel',
#  'color bearer',
#  'color guard',
#  'color sergeant',
#  'combat pilot',
#  'comber',
#  'command sergeant major',
#  'commandant',
#  'commander',
#  'commander in chief',
#  'commanding officer',
#  'commando',
#  'commercial traveler',
#  'commercial traveller',
#  'commissar',
#  'commissioned military officer',
#  'commissioned naval officer',
#  'commissioned officer',
#  'commodore',
#  'common soldier',
#  'companion',
#  'company man',
#  'compositor',
#  'comptroller general',
#  'comptroller of the currency',
#  'conductor',
#  'conductress',
#  'confederate',
#  'confederate soldier',
#  'conscript',
#  'construction worker',
#  'consul',
#  'cook',
#  'cookie',
#  'cooky',
#  'cooper',
#  'copilot',
#  'coppersmith',
#  'copy editor',
#  'copyist',
#  'copyreader',
#  'copywriter',
#  'cordon bleu',
#  'cornhusker',
#  'corporal',
#  'cosmetician',
#  'counterman',
#  'counterperson',
#  'counterwoman',
#  'coureur de bois',
#  'courser',
#  'courtier',
#  'cover girl',
#  'cowboy',
#  'cowgirl',
#  'cowhand',
#  'cowherd',
#  'cowman',
#  'cowpoke',
#  'cowpuncher',
#  'cox',
#  'coxswain',
#  'coyote',
#  'craftsman',
#  'crew member',
#  'crewman',
#  'cropper',
#  'cuirassier',
#  'cupbearer',
#  'currier',
#  'cutter',
#  'da',
#  'dairymaid',
#  'dairyman',
#  'daniel',
#  'darner',
#  'day laborer',
#  'day labourer',
#  'deacon',
#  'deaconess',
#  'deckhand',
#  'decoy',
#  'deer hunter',
#  'deliverer',
#  'delivery boy',
#  'deliveryman',
#  'demonstrator',
#  'dental assistant',
#  'dental hygienist',
#  'dental technician',
#  'denturist',
#  'deputy',
#  'desk clerk',
#  'desk officer',
#  'devil dog',
#  'die-sinker',
#  'diemaker',
#  'diesinker',
#  'digger',
#  'dining-room attendant',
#  'diplomat',
#  'diplomatic minister',
#  'diplomatist',
#  'dishwasher',
#  'disinfestation officer',
#  'dispatcher',
#  'district attorney',
#  'ditch digger',
#  'dock worker',
#  'dock-walloper',
#  'docker',
#  'dockhand',
#  'dockworker',
#  'dog catcher',
#  'doge',
#  'dogfighter',
#  'domestic',
#  'domestic help',
#  'doorkeeper',
#  'double dipper',
#  'doughboy',
#  'doula',
#  'draftee',
#  'draftsman',
#  'draftsperson',
#  'dragger',
#  'dragoon',
#  'draughtsman',
#  'dresser',
#  "dressmaker's model",
#  'drill instructor',
#  'drill master',
#  'driver',
#  'drover',
#  'drudge',
#  'duck hunter',
#  'dyer',
#  'earner',
#  'editor',
#  'editor in chief',
#  'elder',
#  'elected official',
#  'electrician',
#  'electroplater',
#  'embalmer',
#  'embassador',
#  'employable',
#  'employee',
#  'enforcer',
#  'engraver',
#  'enlisted man',
#  'enlisted officer',
#  'enlisted person',
#  'enlisted woman',
#  'ensign',
#  'enumerator',
#  'envoy',
#  'envoy extraordinary',
#  'equerry',
#  'escort',
#  'esquire',
#  'esthetician',
#  'event planner',
#  'ex-serviceman',
#  'excavator',
#  'exciseman',
#  'executive officer',
#  'executive secretary',
#  'expurgator',
#  'facilitator',
#  'factory worker',
#  'factotum',
#  'falconer',
#  'faller',
#  'familiar',
#  'famulus',
#  'farm worker',
#  'farmerette',
#  'farmhand',
#  'farrier',
#  'fashion model',
#  'fed',
#  'federal',
#  'federal agent',
#  'federal official',
#  'fellah',
#  'feller',
#  'ferryman',
#  'field hand',
#  'field marshal',
#  'field officer',
#  'field-grade officer',
#  'fieldhand',
#  'fighter pilot',
#  'file clerk',
#  'filer',
#  'filing clerk',
#  'fille de chambre',
#  'finisher',
#  'fire marshall',
#  'fire warden',
#  'fireman',
#  'first lieutenant',
#  'first mate',
#  'first sergeant',
#  'fisher',
#  'fisherman',
#  'five-star admiral',
#  'fixer',
#  'flag captain',
#  'flag officer',
#  'flanker',
#  'fleet admiral',
#  'flier',
#  'flight attendant',
#  'flight engineer',
#  'floater',
#  'floorwalker',
#  'flower girl',
#  'flunkey',
#  'flunky',
#  'flyer',
#  'fo',
#  'fodder',
#  'foot soldier',
#  'footman',
#  'footslogger',
#  'forest fire fighter',
#  'forger',
#  'forty-niner',
#  'founder',
#  'fowler',
#  'framer',
#  'free lance',
#  'free-lance',
#  'freelance',
#  'freelancer',
#  'fresh fish',
#  'fry cook',
#  'full admiral',
#  'full general',
#  'fuller',
#  'fumigator',
#  'functionary',
#  'funeral director',
#  'funeral undertaker',
#  'furniture maker',
#  'fusilier',
#  'g. l. von blucher',
#  'gaffer',
#  'gallant',
#  'galley slave',
#  'galvaniser',
#  'galvanizer',
#  'gandy dancer',
#  'gardener',
#  'garment cutter',
#  'garnishee',
#  'gas fitter',
#  'gasman',
#  'gatherer',
#  'gaucho',
#  'gebhard leberecht von blucher',
#  'gem cutter',
#  'general',
#  'general officer',
#  'generalissimo',
#  'gentleman',
#  "gentleman's gentleman",
#  'george f. kennan',
#  'george frost kennan',
#  'gilder',
#  'gillie',
#  'gipsy',
#  'girl friday',
#  'glass cutter',
#  'glass-cutter',
#  'glassblower',
#  'glassworker',
#  'glazer',
#  'glazier',
#  'gleaner',
#  'goat herder',
#  'goatherd',
#  'gob',
#  'gofer',
#  'gold digger',
#  'gold miner',
#  'gold panner',
#  'gold-beater',
#  'goldbeater',
#  'goldbrick',
#  'golf caddie',
#  'gondolier',
#  'gondoliere',
#  'grand inquisitor',
#  'gravedigger',
#  'grease monkey',
#  'green beret',
#  'grenade thrower',
#  'grenadier',
#  'greyback',
#  'grigori aleksandrovich potemkin',
#  'grigori potemkin',
#  'grigori potyokin',
#  'grip',
#  'grocery boy',
#  'groom',
#  'groomsman',
#  'groundkeeper',
#  'groundskeeper',
#  'groundsman',
#  'group captain',
#  'guard of honor',
#  'guardsman',
#  'guest worker',
#  'guestworker',
#  'guide',
#  'gunner',
#  'gunnery sergeant',
#  'gunsmith',
#  'gurkha',
#  'gutter',
#  'gypsy',
#  'hairdresser',
#  'hairstylist',
#  'hand',
#  'handmaid',
#  'handmaiden',
#  'handyman',
#  'hanger',
#  'hangover',
#  'hard hat',
#  'hard worker',
#  'harpooneer',
#  'harpooner',
#  'harvester',
#  'hatcheck girl',
#  'hatchet man',
#  'hawker',
#  'headwaiter',
#  'hearing examiner',
#  'hearing officer',
#  'heaver',
#  'hedger',
#  'helmsman',
#  'help',
#  'helper',
#  'herder',
#  'herdsman',
#  'hewer',
#  'high commissioner',
#  'highlander',
#  'hire',
#  'hired hand',
#  'hired help',
#  'hired man',
#  'hireling',
#  'hod carrier',
#  'hodman',
#  'holdover',
#  'home help',
#  'honor guard',
#  'horse wrangler',
#  'horseshoer',
#  'hospital attendant',
#  'hostess',
#  'hostler',
#  'hotel clerk',
#  'hotel desk clerk',
#  'house painter',
#  'house servant',
#  'housebreaker',
#  'housekeeper',
#  'housemaid',
#  'housewrecker',
#  'hunter',
#  'huntress',
#  'huntsman',
#  'hussar',
#  'iceman',
#  'incumbent',
#  'independent',
#  'indexer',
#  'indian agent',
#  'inductee',
#  'infantryman',
#  'inquisitor',
#  'inspector general',
#  'instrument',
#  'internal revenue agent',
#  'internuncio',
#  'invalidator',
#  'itinerant',
#  'jack',
#  'jack of all trades',
#  'jack-tar',
#  'janissary',
#  'jawan',
#  'jobholder',
#  'johnny',
#  'johnny reb',
#  'joiner',
#  'journeyman',
#  'judge',
#  'judge advocate',
#  'judge advocate general',
#  'jurist',
#  'justice',
#  'justice of the peace',
#  'justiciar',
#  'justiciary',
#  'kamikaze',
#  'kennan',
#  'kitchen help',
#  'kitchen police',
#  'knacker',
#  'kp',
#  'labor coach',
#  'laborer',
#  'labourer',
#  'lacer',
#  'lackey',
#  "lady's maid",
#  'lame duck',
#  'laminator',
#  'lamplighter',
#  'lance corporal',
#  'lancer',
#  'lapidary',
#  'lapidist',
#  'lascar',
#  'lasher',
#  'lather',
#  'laundress',
#  'laundryman',
#  'laundrywoman',
#  'leatherneck',
#  'ledgeman',
#  'legal assistant',
#  'legionary',
#  'legionnaire',
#  'lens maker',
#  'letter carrier',
#  'letterer',
#  'licenser',
#  'lieutenant',
#  'lieutenant colonel',
#  'lieutenant commander',
#  'lieutenant general',
#  'lieutenant governor',
#  'lieutenant jg',
#  'lieutenant junior grade',
#  'lifeguard',
#  'lifesaver',
#  'light colonel',
#  'lighterman',
#  'line officer',
#  'line worker',
#  'lineman',
#  'linesman',
#  'linkboy',
#  'linkman',
#  'lion-hunter',
#  'lister',
#  'litter-bearer',
#  'liveryman',
#  'loader',
#  'lobsterback',
#  'lobsterman',
#  'lockkeeper',
#  'lockman',
#  'lockmaster',
#  'locksmith',
#  'logger',
#  'longshoreman',
#  'lovely',
#  'luddite',
#  'lumberjack',
#  'lumberman',
#  'lumper',
#  'luthier',
#  'mace',
#  'macebearer',
#  'macer',
#  'machine gunner',
#  'machinist',
#  'magistrate',
#  'mahout',
#  'maid',
#  'maid of honor',
#  'maidservant',
#  'mail carrier',
#  'mail clerk',
#  'mailman',
#  'maintenance man',
#  "maitre d'",
#  "maitre d'hotel",
#  'major',
#  'major-domo',
#  'major-general',
#  'man',
#  'man friday',
#  'man-at-arms',
#  'managing editor',
#  'manakin',
#  'mandarin',
#  'manicurist',
#  'manikin',
#  'mannequin',
#  'mannikin',
#  'manservant',
#  'manual laborer',
#  'mapper',
#  'marcher',
#  'marine',
#  'mariner',
#  'marshal',
#  'marshall',
#  'mason',
#  'master',
#  'master sergeant',
#  'master-at-arms',
#  'mate',
#  'matron of honor',
#  'mechanic',
#  'medical social worker',
#  'melter',
#  'mender',
#  'menial',
#  'metalworker',
#  'midinette',
#  'military adviser',
#  'military advisor',
#  'military man',
#  'military officer',
#  'military personnel',
#  'military recruit',
#  'military volunteer',
#  'militiaman',
#  'milkmaid',
#  'milkman',
#  'mill-girl',
#  'mill-hand',
#  'miller',
#  'millwright',
#  'minder',
#  'miner',
#  'mineworker',
#  'minister',
#  'minister plenipotentiary',
#  'minter',
#  'minuteman',
#  'mixologist',
#  'model',
#  'moneyer',
#  'monitrice',
#  'moonlighter',
#  'mopper',
#  'mortician',
#  'mounter',
#  'mover',
#  'mud digger',
#  'mule driver',
#  'mule skinner',
#  'muleteer',
#  'musketeer',
#  'muzzler',
#  'nailer',
#  'naval commander',
#  'naval officer',
#  'navigator',
#  'navvy',
#  'navy man',
#  'navy seal',
#  'newsboy',
#  'newspaper editor',
#  'noncom',
#  'noncombatant',
#  'noncommissioned officer',
#  'notary',
#  'notary public',
#  'noticer',
#  'nullifier',
#  'nuncio',
#  "nurse's aide",
#  'nursing aide',
#  'oarsman',
#  'oarswoman',
#  'occupier',
#  'oceanaut',
#  'odd-job man',
#  'office boy',
#  'office-bearer',
#  'officeholder',
#  'officer',
#  'official',
#  'oil rigger',
#  'oiler',
#  'oilman',
#  'old salt',
#  'optician',
#  'orderly',
#  'orderly sergeant',
#  'ordinary',
#  'organization man',
#  'ostler',
#  'p.o.',
#  'packer',
#  'paddler',
#  'page',
#  'painter',
#  'pantryman',
#  'papal nuncio',
#  'paper-pusher',
#  'paperboy',
#  'paperer',
#  'paperhanger',
#  'para',
#  'paralegal',
#  'paramedic',
#  'paramedical',
#  'paraprofessional',
#  'paratrooper',
#  'parer',
#  'parlormaid',
#  'parlourmaid',
#  'part-timer',
#  'paster',
#  'pastry cook',
#  'pawn',
#  'peacekeeper',
#  'peasant',
#  'peeler',
#  'pencil pusher',
#  'penpusher',
#  'pensionary',
#  'peon',
#  'perfecter',
#  'persona grata',
#  'persona non grata',
#  'petty officer',
#  'phlebotomist',
#  "photographer's model",
#  'piano tuner',
#  'picker',
#  'pigman',
#  'pilate',
#  'pilot',
#  'pin-up',
#  'pipe fitter',
#  'pistoleer',
#  'pitchman',
#  'pitman',
#  'placeman',
#  'placer miner',
#  'placeseeker',
#  'plaiter',
#  'planter',
#  'plasterer',
#  'platelayer',
#  'plater',
#  'pledge taker',
#  'plenipotentiary',
#  'plier',
#  'plotter',
#  'ploughman',
#  'ploughwright',
#  'plower',
#  'plowman',
#  'plowwright',
#  'plumber',
#  'plyer',
#  'po',
#  'poilu',
#  'point man',
#  'political commissar',
#  'pontius pilate',
#  'porter',
#  'poser',
#  'postal clerk',
#  'poster',
#  'postman',
#  'postmaster general',
#  'potboy',
#  'potemkin',
#  'pothunter',
#  'potman',
#  'potter',
#  'potyokin',
#  'powder monkey',
#  'power worker',
#  'power-station worker',
#  'praetor',
#  'presbyter',
#  'preserver',
#  'pressman',
#  'pretor',
#  'printer',
#  'private',
#  'privateer',
#  'privateersman',
#  'probation officer',
#  'processor',
#  'proconsul',
#  'procurator',
#  'projectionist',
#  'prompter',
#  'proofreader',
#  'property man',
#  'property master',
#  'propman',
#  'prosecuting attorney',
#  'prosecuting officer',
#  'prosecutor',
#  'prospector',
#  'protestant deacon',
#  'provincial',
#  'pruner',
#  'public prosecutor',
#  'public servant',
#  'publican',
#  'puller',
#  'pullman porter',
#  'puncher',
#  'punter',
#  'purser',
#  'qadi',
#  'quaestor',
#  'quarrier',
#  'quarryman',
#  'quartermaster',
#  'quartermaster general',
#  'racker',
#  'ragsorter',
#  'rail-splitter',
#  'railroad man',
#  'railroader',
#  'railway man',
#  'railwayman',
#  'ranch hand',
#  'ranger',
#  'ranker',
#  'rapporteur',
#  'rat',
#  'rat-catcher',
#  'raw recruit',
#  'reader',
#  'reaper',
#  'rear admiral',
#  'reb',
#  'rebel',
#  'receptionist',
#  'record-keeper',
#  'recorder',
#  'recruit',
#  'recruiter',
#  'recruiting-sergeant',
#  'redact',
#  'redactor',
#  'redcap',
#  'redcoat',
#  'refiner',
#  'refinisher',
#  'registrar',
#  'regular',
#  'regulator',
#  'remover',
#  'renovator',
#  'rent collector',
#  'repairer',
#  'repairman',
#  'reservist',
#  'restaurant attendant',
#  'restorer',
#  'retainer',
#  'returning officer',
#  'reviser',
#  'rewrite man',
#  'rewriter',
#  'rifleman',
#  'rigger',
#  'right-hand man',
#  'riveter',
#  ...]

# %% [markdown]
# #### Extract all nouns from report text and get frequencies

# %%
# extract all nouns from report text
pd.set_option("display.max_colwidth", 50)
lemma = nltk.WordNetLemmatizer()

def preproc4(tt):
    wpos = pos_tag(word_tokenize(tt))
    lemmas = []
    for w, pos in wpos:
        if pos in {'NN','NNS'}:
            lemmas.append(lemma.lemmatize(w.lower(), pos = 'n'))
    return lemmas

text4 = df['text']
text4_n = text4.apply(preproc4)
text4 = [t for t in text4]
text4_n
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0       [forklift, employer, bale, paper, product, col...
# 1       [trailer, trailer, ground, abdomen, fall, heig...
# 2       [construction, company, installation, service,...
# 3       [forklift, rider, cube, coax, cable, copper, w...
# 4       [vacuum, truck, driver, operator, water, power...
#                               ...
# 9995    [rail, car, metal, shop, control, box, waist, ...
# 9996    [p.m., steam, locomotive, resort, train, block...
# 9997    [remote, rail, engine, metal, submarine, car, ...
# 9998    [fireman, engineer, cab, steam, locomotive, ra...
# 9999    [p.m., contract, worker, refinery, shift, way,...
# Name: text, Length: 10000, dtype: object

# %%
# flatten unique list and obtain freq distributions
text4_set = [list(set(f)) for f in text4_n]
text4_flat = [w for t in text4_set for w in t]

fd_n = FreqDist(text4_flat)
fd_n.most_common(10)
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [('employee', 3623),
#  ('injury', 1986),
#  ('p.m.', 1798),
#  ('hospital', 1783),
#  ('hand', 1672),
#  ('a.m.', 1573),
#  ('foot', 1563),
#  ('day', 1543),
#  ('area', 1504),
#  ('coworker', 1457)]

# %%
# find all unique tokens matching body parts
body_tokens = [(w, fd_n[w]) for w in fd_n.keys() if w in body]
body_tokens = sorted(body_tokens, key=lambda x: x[1], reverse=True)
body_tokens[:10]
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [('hand', 1672),
#  ('foot', 1563),
#  ('area', 1504),
#  ('side', 1235),
#  ('head', 1066),
#  ('finger', 1016),
#  ('arm', 804),
#  ('leg', 748),
#  ('system', 648),
#  ('body', 600)]

# %% [markdown]
# #### 3. Which part of the human body is injured most?
# The most common body parts involved in accidents are 'hand', 'foot', 'head' and 'finger'. Looks like typically the extremities are involved in such accidents. This information may be potentially useful for enhancing workplace safety measures such as better protective gear for hands and feet, and also the use of appropriate headgear for specific activities.

# %%
# find all unique tokens matching occupations
worker_tokens = [(w, fd_n[w]) for w in fd_n.keys() if w in worker]
worker_tokens = sorted(worker_tokens, key=lambda x: x[1], reverse=True)
worker_tokens[:10]
# Out:
# C:\Users\desmo\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [('employee', 3623),
#  ('hand', 1672),
#  ('driver', 423),
#  ('laborer', 273),
#  ('mechanic', 202),
#  ('paramedic', 178),
#  ('technician', 174),
#  ('conductor', 174),
#  ('help', 169),
#  ('loader', 165)]

# %% [markdown]
# #### 4. What are the more risky occupations involved in such accidents?
# The more risky occupations involved in such accidents are 'driver', 'laborer', 'mechanic', 'paramedic', 'technician', and 'conductor'. As expected, most of the occupations are related to manual labour except for 'paramedics'. The term 'paramedic' may have been picked up as the reports may have mentioned the first responders attending to the victims, and these paramedics may not have been involved in the accident in the first place. It's also important to note that there were many reports stating just 'employee', which is a generic term. It may be helpful to further deep dive into the occupations of these employees to explore if there are other job roles which were not identified.
